# %% [markdown]
# # [Project Name]
#
# **Author:** Olaf König
# **Date:** [YYYY-MM-DD]

# %% [markdown]
# # Objectives
#
# **Main goal:** [What this script accomplishes]
#
# **Goals:**
# - [Objective 1]
# - [Objective 2]
#
# ---

# %% [markdown]
# ## Inputs
#
# | Object Name | File Name | Source | Extension |
# |-------------|-----------|--------|-----------|
# | [df_name] | [filename] | [description/source] | .csv |
# | [df_name] | [filename] | [description/source] | .xlsx |
#
# ## Outputs
#
# | Object Name | File Name | Source | Extension |
# |-------------|-----------|--------|-----------|
# | [df_clean] | [filename] | [description/what it contains] | .csv |
# | [plot_main] | [filename] | [description/what it contains] | .png |
#
# ---

# %% [markdown]
# # Setup

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# File handling
import os
from pathlib import Path

# Configuration
plt.style.use('seaborn-v0_8-whitegrid')
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format) # No scientific notation

# %%
# Define project paths
input_raw_dir = Path("input/raw")
input_processed_dir = Path("input/processed")
output_dir = Path("output")

# Create directories if they don't exist
input_raw_dir.mkdir(parents=True, exist_ok=True)
input_processed_dir.mkdir(parents=True, exist_ok=True)
output_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ---
#
# # Data Import

# %%
# Load data
# df = pd.read_csv(input_raw_dir / "data.csv")
# df_excel = pd.read_excel(input_raw_dir / "data.xlsx")

# %% [markdown]
# ---
#
# # Main Analysis

# %%
# Analysis code here

# %% [markdown]
# ---
#
# # Export Results

# %%
# Save processed data
# df_clean.to_csv(input_processed_dir / "data_clean.csv", index=False)

# Save plots
# plt.savefig(output_dir / "plot.png", dpi=300, bbox_inches='tight')
# plt.show()
